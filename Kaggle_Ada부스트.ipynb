# %% [markdown]
# <a href="https://colab.research.google.com/github/truffleToast/DeepLearning/blob/main/Kaggle_Ada%EB%B6%80%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt #그래프 그리기
import statsmodels.graphics.tsaplots as sgt #  acf, pcaf 그리기
import seaborn as sns #heatmap 사용을 위해 import

# %%
raw_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/deepLearning/Kaggle/data/continuous_factory_process.csv", index_col ="time_stamp")
raw_sub=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/deepLearning/Kaggle/data/submission_data.csv", index_col="time_stamp")

# %%
df = raw_df.drop(columns=[col for col in raw_df.columns if col.endswith('.Setpoint')]) #setPoint제거
sub = raw_sub.drop(columns=[col for col in raw_df.columns if col.endswith('.Setpoint')]) #setPoint제거

# %%
#머신러닝 순서
# 1. 문제 제시 - 완료

# %%
# 2. 데이터 수집 - 완료
# 내가 필요한 데이터를 바탕으로
firstX = df.iloc[:,:38] #machine3까지의 값
firsty =df.iloc[:,41:56] #첫번째 y
SecondX = df.iloc[:,41:70] # 두번째 X
SecondX1 =df.iloc[:,41:56] #추출값
SecondX2 =df.iloc[:,56:70] # 머신 4,5
Secondy =df.iloc[:,70:] # 머신 4,5까지 돌린 추출값
RfirstX = sub.iloc[:,:38] #machine3까지의 값
Rfirsty =sub.iloc[:,41:56] #첫번째 y = Stage1
RSecondX1 =sub.iloc[:,41:56]  #첫번째 y = Stage1
RSecondX2 =sub.iloc[:,56:70]  # 머신 4,5
RSecondy =sub.iloc[:,70:]# 머신 4,5까지 돌린 추출값

# %%
# 'firstX'가 데이터프레임이라고 가정합니다.
for i in range(len(firstX.columns)):
    plt.figure()  # 각 그래프를 위한 새로운 창 생성
    plt.plot(firstX.index, firstX.iloc[:, i])
    plt.title("attributes")  # 그래프의 제목 설정 (열 이름을 사용합니다)
    plt.xlabel('time_stamp')  # x축 레이블 설정 (한글로 변경)
    plt.ylabel(firstX.columns[i])  # y축 레이블 설정 (열 이름을 사용합니다)
    plt.show()  # 그래프 표시

# %%
# 'SecondX2'가 데이터프레임이라고 가정합니다.
for i in range(len(SecondX2.columns)):
    plt.figure()  # 각 그래프를 위한 새로운 창 생성
    plt.plot(SecondX2.index, SecondX2.iloc[:, i])
    plt.title("attributes")  # 그래프의 제목 설정 (열 이름을 사용합니다)
    plt.xlabel('time_stamp')  # x축 레이블 설정 (한글로 변경)
    plt.ylabel(SecondX2.columns[i])  # y축 레이블 설정 (열 이름을 사용합니다)
    plt.show()  # 그래프 표시

# %%
#각각의 밸류값

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.multioutput import MultiOutputRegressor

ad =AdaBoostRegressor()
multi =MultiOutputRegressor(ad)
multi.fit(firstX, firsty)
# Out:
# MultiOutputRegressor(estimator=AdaBoostRegressor())

# %% [markdown]
# # 모델1

# %%
# 모델학습
grid_search1.fit(firstX, firsty)

# %%
print('최고의 파라미터:' , grid_search1.best_params_)
print('최고 점수', grid_search1.best_score_)
